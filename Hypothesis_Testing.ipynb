# %%
# %pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.18.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: numpy<2.8,>=2.0.0 in ./venv/lib/python3.13/site-packages (from scipy) (2.5.3)
# Downloading scipy-1.18.1-cp313-cp313-macosx_14_0_arm64.whl (20.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 10.6 MB/s  0:00:01 eta 0:00:01
# Installing collected packages: scipy
# Successfully installed scipy-1.18.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.stats import norm

population_mean = 800
sample_mean = 790
standard_error = 7.5
alpha = 0.05

z_score = (sample_mean - population_mean)/standard_error

# two tailed test. (Always make sure if we are working with two tailed test we have to multiply by 2)
p_value = 2 * norm.cdf(z_score)
print(p_value)
if p_value > alpha:
    print('Failed to reject the null Hypothesis: average lifespan of light bulbs is approximately 800 hrs')
else:
    print('Reject the null Hypothesis: average lifespan of light bulbs is not 800 hrs')
# Out:
# 0.18242243945173575
# Failed to reject the null Hypothesis: average lifespan of light bulbs is approximately 800 hrs

# %% [markdown]
# You work for a company that produces three types of energy drinks. The company wants to know if the average caffeine content differs significantly among these three types. You collect data on the caffeine content (in milligrams) from five samples of each drink:
#
# Energy Drink A: 105 mg, 110 mg, 98 mg, 107 mg, 103 mg
#
# Energy Drink B: 130 mg, 125 mg, 132 mg, 128 mg, 129 mg
#
# Energy Drink C: 120 mg, 115 mg, 117 mg, 119 mg, 121 mg
#
# Question: Is there a statistically significant difference in the average caffeine content between these three types of energy drinks?

# %%
import scipy.stats as stats

group_A = [105, 110, 98, 107, 103]
group_B = [130, 125, 132, 128, 129]
group_C = [120, 115, 117, 119, 121]
alpha = 0.05

f_value,p_value = stats.f_oneway(group_A,group_B,group_C)

if alpha < p_value:
    print("Fail to reject the null hypothesis meaning there is no significant difference in the average caffeine of above three energy drink")
else:
    print("Reject the null hypthesis meaning there is a significant difference in the average caffeine content of the above three energy drink")

print(p_value)
# Out:
# Reject the null hypthesis meaning there is a significant difference in the average caffeine content of the above three energy drink
# 2.9844274607194716e-07
